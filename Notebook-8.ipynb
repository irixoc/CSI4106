# %% [markdown]
# # Notebook 8 - Knowledge Representation (KR)

# %% [markdown]
# CSI4106 Artificial Intelligence  \
# Fall 2021 \
# Version 1 (2020) prepared by Julian Templeton and Caroline Barrière.  Version 2 (2021) revised by Caroline Barrière.

# %% [markdown]
# ***INTRODUCTION***:
#
# When reading text, understanding the type of entities within the text helps to infer additional information about the entity. For example, if a text mentions *Canada*, knowing that it is a GPE (geopolitical entity), already indicates to us that this entity has a supercify, a population, etc. Through the use of Named Entity Recognition (NER), we are able to determine whether an entity is a Person, Organization, Country, ...
#
# When exploring text online, we also occassionally see entities have clickable links to webpages with more information on the entity. This is a form of enhancement of the text to allow readers to easily access the information needed to understand each entity from the text and its content.  If we take the example of Canada again, if we transform it into [Canada](https://en.wikipedia.org/wiki/Canada), using entity linking we access more information.
#
# In this notebook we will be revisiting the Covid-19 related news dataset from notebook 7 to explore how we can improve spaCy's NER and enhance the text from the news articles through the use of entity linking. This will be done in three parts:
#
# (1) we explore the results of spaCy's NER  \
# (2) we use text coherence for post-processing spaCy's NER results \
# (3) we perform text enhancement with entity linking.
#
# This notebook uses libraries that have been used in previous notebooks, including spaCy and pandas.

# %% [markdown]
# ***HOMEWORK***:
# Go through the notebook by running each cell, one at a time.
# Look for **(TO DO)** for the tasks that you need to perform. Do not edit the code outside of the questions which you are asked to answer unless specifically asked. Once you're done, sign the notebook (at the end of the notebook), rename it to *StudentNum-LastName-Notebook8.ipynb* and submit it.
#
# *The notebook will be marked on 30.
# Each **(TO DO)** has a number of points associated with it.*
# ***

# %%
# Before starting we will import every module that we will be using
import spacy
import pandas as pd

# %%
# The core spacy object can be used for tokenization, lemmatization, POS Tagging, NER, ...
# Note that this is specifically for the English language and requires the English package to be installed
# via pip to work as intended.

# sp = spacy.load('en')

# If the above causes an error after installing the package 
# then install the package as below
# !spacy download en_core_web_sm
sp = spacy.load('en_core_web_sm')

# %% [markdown]
# Similarly to the last notebook, the dataset is provided on Brightspace (Module 8) along with this notebook, but details regarding Covid-19 news dataset can be found [here](https://www.kaggle.com/ryanxjhan/cbc-news-coronavirus-articles-march-26?select=news.csv). The first thing that we will do, as usual, is load the file into a pandas dataframe.

# %%
# Read the dataset, show top ten rows
df = pd.read_csv("news.csv")
df.head(10)
# Out:
#   Unnamed: 0                                            authors  \
# 0          0                                                 []
# 1          1                                                 []
# 2          2                             ['The Canadian Press']
# 3          3                                                 []
# 4          4                                                 []
# 5          5  ['Senior Writer', 'Chris Arsenault Is A Senior...
# 6          6                                       ['Cbc News']
# 7          7                                       ['Cbc News']
# 8          8  ['Senior Writer', "Adam Miller Is Senior Digit...
# 9          9                                ['Thomson Reuters']
#
#                                                title      publish_date  \
# 0  'More vital now:' Gay-straight alliances go vi...   2020-05-03 1:30
# 1  Scientists aim to 'see' invisible transmission...   2020-05-02 8:00
# 2  Coronavirus: What's happening in Canada and ar...  2020-05-02 11:28
# 3  B.C. announces 26 new coronavirus cases, new c...  2020-05-02 18:45
# 4  B.C. announces 26 new coronavirus cases, new c...  2020-05-02 18:45
# 5  Brazil has the most confirmed COVID-19 cases i...   2020-05-02 8:00
# 6   The latest on the coronavirus outbreak for May 1  2020-05-01 20:43
# 7  Coronavirus: What's happening in Canada and ar...  2020-05-01 11:51
# 8  Did the WHO mishandle the global coronavirus p...   2020-04-30 8:00
# 9  Armed people in Michigan's legislature protest...  2020-04-30 21:37
#
#                                          description  \
# 0  Lily Overacker and Laurell Pallot start each g...
# 1  Some researchers aim to learn more about how t...
# 2  Canada's chief public health officer struck an...
# 3  B.C. provincial health officer Dr. Bonnie Henr...
# 4  B.C. provincial health officer Dr. Bonnie Henr...
# 5  From describing coronavirus as a "little flu,"...
# 6  The latest on the coronavirus outbreak from CB...
# 7  Nova Scotia announced Friday it is immediately...
# 8  The World Health Organization has come under f...
# 9  Hundreds of protesters, some armed, gathered a...
#
#                                                 text  \
# 0  Lily Overacker and Laurell Pallot start each g...
# 1  This is an excerpt from Second Opinion, a week...
# 2  The latest:  The lives behind the numbers: Wha...
# 3  B.C. provincial health officer Dr. Bonnie Henr...
# 4  B.C. provincial health officer Dr. Bonnie Henr...
# 5  With infection rates spiralling, some big city...
# 6    Coronavirus Brief (CBC)  Canada is officiall...
# 7  The latest:  The lives behind the numbers: Wha...
# 8  The World Health Organization has come under f...
# 9  Hundreds of protesters, some armed, gathered a...
#
#                                                  url
# 0  https://www.cbc.ca/news/canada/calgary/gay-str...
# 1  https://www.cbc.ca/news/technology/droplet-tra...
# 2  https://www.cbc.ca/news/canada/coronavirus-cov...
# 3  https://www.cbc.ca/news/canada/british-columbi...
# 4  https://www.cbc.ca/news/canada/british-columbi...
# 5  https://www.cbc.ca/news/world/brazil-has-the-m...
# 6  https://www.cbc.ca/news/the-latest-on-the-coro...
# 7  https://www.cbc.ca/news/canada/coronavirus-cov...
# 8  https://www.cbc.ca/news/health/coronavirus-who...
# 9  https://www.cbc.ca/news/world/protesters-michi...

# %% [markdown]
# **PART 1 - SpaCy's NER**
#
# Let's start by looking at the NER that is performed by spaCy.  SpaCy's documentation does not tell us how exactly their NER is done (certainly their trade secret), but we can at least look at the results.
#
# As we've talked about in previous notebooks, when evaluating a process or a tool, we can do quantitative or **qualitative evaluation** of results.  In this notebook, we work at a qualitative level, meaning that we are not measuring metrics such as precision/recall on a large amount of data, but rather printing results of a few examples and try to understand these results.

# %% [markdown]
# Below is the same sentence example as in the last notebook, for which we had looked at POS-tagging and other linguistic processes.  We now use this sentence to show how to access spaCy's NER type predictions for tokens in a text.

# %%
# Same example from notebook 7, recall that we loop through the iterator found in the .ents property of a parsed sentence
sentence_example = "Government guidelines in Canada recommend that people stay at least two metres away from others as part of physical distancing measures to curb the spread of COVID-19."
sentence_example_content = sp(sentence_example)
# Loop through all tokens that contain a NER type and print the token along with the corresponding NER type
for token in sentence_example_content.ents:
    print("\"" + token.text + "\" is a " + token.label_ )
# Out:
# "Canada" is a GPE

# %% [markdown]
# **(TO DO) Q1 - 5 marks**
#
# In the text of **second document** (index 1) of our corpus of documents, find out which words are *PER* (spaCy uses the *PERSON* type, rather than *PER*), *ORG* (Organization), and *GPE* (Geopolitical Entity). You must do the following for this question:
# a) (2 marks) Print each element in the text tagged as *PER*, *ORG*, and *GPE* along with its NER type from spaCy.
# b) (1 mark) Is the majority of outputs correct? Provide two examples of incorrect outputs from (a).
# c) (2 marks) Do any of the problems with the NER type predictions come from an earlier step in the NLP pipeline that is performed by spaCy? Describe the problem for two examples of your output from (a).

# %%
# ANSWER Q1(a) - 2 marks
# Select the second document (index 1)
doc = df["text"][1]
doc_content = sp(doc)

# Print each PER, ORG, GPE along with its type
for token in doc_content.ents:
    if token.label_ == "PERSON":
        print("PER: \"" + token.text + "\", spaCy NRE type: " + token.label_)
    if token.label_ == "ORG" or token.label_ == "GPE":
        print(token.label_ +": \"" + token.text + "\", spaCy NRE type: " + token.label_ )
# Out:
# PER: "COVID-19", spaCy NRE type: PERSON
# PER: "COVID-19", spaCy NRE type: PERSON
# ORG: "the World Health Organization", spaCy NRE type: ORG
# ORG: "Touches", spaCy NRE type: ORG
# ORG: "WHO", spaCy NRE type: ORG
# ORG: "the Public Health Agency of", spaCy NRE type: ORG
# GPE: "Canada", spaCy NRE type: GPE
# PER: "W.F. Wells", spaCy NRE type: PERSON
# ORG: "the Harvard School of Public Health", spaCy NRE type: ORG
# PER: "Wells", spaCy NRE type: PERSON
# GPE: "Canada", spaCy NRE type: GPE
# PER: "Lydia Bourouiba", spaCy NRE type: PERSON
# ORG: "the Fluid Dynamics of Disease Transmission Laboratory", spaCy NRE type: ORG
# ORG: "the Massachusetts Institute of Technology", spaCy NRE type: ORG
# PER: "Bourouiba", spaCy NRE type: PERSON
# PER: "Mark Loeb", spaCy NRE type: PERSON
# PER: "Hamilton", spaCy NRE type: PERSON
# ORG: "McMaster University ", spaCy NRE type: ORG
# ORG: "RNA", spaCy NRE type: ORG
# GPE: "Wuhan", spaCy NRE type: GPE
# GPE: "China", spaCy NRE type: GPE
# GPE: "Nebraska", spaCy NRE type: GPE
# PER: "COVID-19", spaCy NRE type: PERSON
# GPE: "Canada", spaCy NRE type: GPE
# PER: "Gary Moore", spaCy NRE type: PERSON
# PER: "Allison McGeer", spaCy NRE type: PERSON
# ORG: "Sinai Health", spaCy NRE type: ORG
# GPE: "Toronto", spaCy NRE type: GPE
# PER: "COVID-19", spaCy NRE type: PERSON
# ORG: "McGeer", spaCy NRE type: ORG
# PER: "COVID-19", spaCy NRE type: PERSON
# ORG: "McGeer", spaCy NRE type: ORG
# ORG: "Bourouiba", spaCy NRE type: ORG
# ORG: "Bourouiba", spaCy NRE type: ORG
# ORG: "Credit Lydia Bourouiba/MIT/", spaCy NRE type: ORG
# PER: "JAMA Networks", spaCy NRE type: PERSON
# PER: "Samira Mubareka", spaCy NRE type: PERSON
# GPE: "Toronto", spaCy NRE type: GPE
# PER: "Bourouiba", spaCy NRE type: PERSON
# PER: "COVID-19", spaCy NRE type: PERSON
# ORG: "N95", spaCy NRE type: ORG
# GPE: "U.S.", spaCy NRE type: GPE
# PER: "Justin Trudeau", spaCy NRE type: PERSON
# ORG: "the New England Journal of Medicine", spaCy NRE type: ORG
# ORG: "the U.S. National Institutes of Health", spaCy NRE type: ORG
# ORG: "U.S. National Institutes of Health", spaCy NRE type: ORG
# PER: "COVID-19", spaCy NRE type: PERSON
# ORG: "Journal of the Royal Society Interface", spaCy NRE type: ORG
# GPE: "U.S.", spaCy NRE type: GPE
# GPE: "Singapore", spaCy NRE type: GPE
# ORG: "N95", spaCy NRE type: ORG
# PER: "Gary S. Settles", spaCy NRE type: PERSON
# ORG: "Penn State University/Journal of the Royal Society Interface", spaCy NRE type: ORG
# ORG: "The World Health Organization", spaCy NRE type: ORG
# GPE: "Los Angeles", spaCy NRE type: GPE
# GPE: "Italy", spaCy NRE type: GPE
# GPE: "Austria", spaCy NRE type: GPE

# %% [markdown]
# **ANSWER Q1 (b) - 1 mark**
#
# The majority of outputs are correct.
#
# Two examples of incorrect outputs are:
# 1. "COVID-19", which is incorrectly labelled as a PERSON
# 2. "Touches", which is incorrectly labelled as a ORG

# %% [markdown]
# **ANSWER Q1 (c) - 2 marks**
#
# "N95" is labelled as ORG. This problem might also be from POS Tagging in the NLP pipeline.
# "COVID-19" is labelled as PERSON. This problem might come from Part of Speech Tagging in the NLP pipeline

# %% [markdown]
# **PART 2 - Text Coherence and coreference chains**
#
# As you saw in Q1, the results of spaCy are quite good, but not perfect.  One main issue with NER (not just in spaCy but in many tools) is that the annotation is performed one entity at a time without consideration of the overall document.
#
# But when looking a the whole document, and knowing that text is usually coherent, we can do some post-processing to spaCy's NER module and correct some mistakes.  By text being coherent, we mean, for example, that if a person is referred to with a particular name, e.g. *McGeer*, chances are that each time we see *McGeer* in the document, it is the same person.  All the mentions of *McGeer* form a coreference chain all refering to a single entity. So it is unlikely that *McGeer* would be once a person and once an organization.  This is not always true, there are numerous counter-examples, but it is a common assumption.  This idea is even the topic of an older much-cited NLP article called "One sense per discourse" (Gale and al. 1992).
#
# With this idea of "one sense per discourse", we will explore two different strategies to use text coherence to post-process the output from the spaCy NER module.
#
# The first strategy (*explored in Q2/Q3*) is to find, among all NER types assigned, which is the most frequent one.  For example, the name *Bourouiba* was assigned 1 time ORG, and 2 times PERSON, so this information can be used to modify the ORG type and change it to PERSON.
#
# The second strategy (explored in Q4) is to try to find a longer surface form in the text.  Since that longer form should be less ambiguous, we can use it to disambiguate the shorter, more ambiguous forms.  For example, *Lydia Bourouiba* occurs in the text and is assigned PERSON.  We can use that information to assign further occurrences of the short form *Bourouiba* to also be PERSON.
#
# Of course, using these methods for text coherence will not work every time, and will unfortunately introduce some errors...  But let's try.  That's what empirical studies are about, we try ideas.

# %% [markdown]
# Let's take again the news article from Q1, but this time, let's show not only GPE, PER, ORG, but rather all the Named Entities found by spaCy.

# %%
# Select document 2
doc = df["text"][1]
# NER
doc_sp = sp(doc)
# Display all entities from the text along with their index in the .ents iterator and the
# corresponding NER type
for i, token in enumerate(doc_sp.ents):
    print(str(i) + ": \"" + token.text + "\" is a " + token.label_ )
# Out:
# 0: "weekly" is a DATE
# 1: "Saturday" is a DATE
# 2: "morning" is a TIME
# 3: "COVID-19" is a PERSON
# 4: "two metres" is a QUANTITY
# 5: "COVID-19" is a PERSON
# 6: "the World Health Organization" is a ORG
# 7: "Touches" is a ORG
# 8: "WHO" is a ORG
# 9: "more than one metre" is a QUANTITY
# 10: "the Public Health Agency of" is a ORG
# 11: "Canada" is a GPE
# 12: "at least two metres" is a QUANTITY
# 13: "two" is a CARDINAL
# 14: "2 metres" is a QUANTITY
# 15: "the 19th century" is a DATE
# 16: "1934" is a DATE
# 17: "W.F. Wells" is a PERSON
# 18: "the Harvard School of Public Health" is a ORG
# 19: "two metres" is a QUANTITY
# 20: "Wells" is a PERSON
# 21: "56,000+" is a QUANTITY
# 22: "Canada" is a GPE
# 23: "Saturday" is a DATE
# 24: "Lydia Bourouiba" is a PERSON
# 25: "the Fluid Dynamics of Disease Transmission Laboratory" is a ORG
# 26: "the Massachusetts Institute of Technology" is a ORG
# 27: "Bourouiba" is a PERSON
# 28: "Canadian" is a NORP
# 29: "Mark Loeb" is a PERSON
# 30: "Hamilton" is a PERSON
# 31: "McMaster University " is a ORG
# 32: "RNA" is a ORG
# 33: "Wuhan" is a GPE
# 34: "China" is a GPE
# 35: "Nebraska" is a GPE
# 36: "COVID-19" is a PERSON
# 37: "Canada" is a GPE
# 38: "Gary Moore" is a PERSON
# 39: "Allison McGeer" is a PERSON
# 40: "Sinai Health" is a ORG
# 41: "Toronto" is a GPE
# 42: "COVID-19" is a PERSON
# 43: "hundreds" is a CARDINAL
# 44: "hours" is a TIME
# 45: "N-95" is a PRODUCT
# 46: "McGeer" is a ORG
# 47: "COVID-19" is a PRODUCT
# 48: "five minutes" is a TIME
# 49: "COVID-19" is a PERSON
# 50: "McGeer" is a ORG
# 51: "Bourouiba" is a ORG
# 52: "Bourouiba" is a ORG
# 53: "up to seven" is a CARDINAL
# 54: "Credit Lydia Bourouiba/MIT/" is a ORG
# 55: "JAMA Networks" is a PERSON
# 56: "Canadian" is a NORP
# 57: "about one kilometre" is a QUANTITY
# 58: "two-metre" is a QUANTITY
# 59: "up to three minutes" is a TIME
# 60: "Samira Mubareka" is a PERSON
# 61: "Sunnybrook Hospital" is a FAC
# 62: "Toronto" is a GPE
# 63: "2-metre" is a QUANTITY
# 64: "Bourouiba" is a PERSON
# 65: "two metres" is a QUANTITY
# 66: "March" is a DATE
# 67: "two metres" is a QUANTITY
# 68: "two-metre" is a QUANTITY
# 69: "Second" is a ORDINAL
# 70: "COVID-19" is a PERSON
# 71: "N95" is a ORG
# 72: "U.S." is a GPE
# 73: "Canadian" is a NORP
# 74: "Justin Trudeau" is a PERSON
# 75: "April 2020" is a DATE
# 76: "the New England Journal of Medicine" is a ORG
# 77: "the U.S. National Institutes of Health" is a ORG
# 78: "0:42" is a TIME
# 79: "U.S. National Institutes of Health" is a ORG
# 80: "less than 10 centimetres" is a QUANTITY
# 81: "COVID-19" is a PERSON
# 82: "2009" is a DATE
# 83: "Journal of the Royal Society Interface" is a ORG
# 84: "2009" is a DATE
# 85: "U.S." is a GPE
# 86: "Singapore" is a GPE
# 87: "N95" is a ORG
# 88: "Gary S. Settles" is a PERSON
# 89: "Penn State University/Journal of the Royal Society Interface" is a ORG
# 90: "The World Health Organization" is a ORG
# 91: "Los Angeles" is a GPE
# 92: "Italy" is a GPE
# 93: "Austria" is a GPE
# 94: "Saturday" is a DATE
# 95: "morning" is a TIME

# %% [markdown]
# **(TO DO) Q2 - 3 marks**
# As you can see in the results, sometimes the same entity was assigned different entity types (e.g. *McGeer* is one time assigned entity type ORG, and one time entity type PERSON) since the NER algorithm looks sentence by sentence.  In the following function, the purpose will be to find all the possible entity types assigned to a single entity.
#
# Complete the definition of the *find_entity_types* function below. This function accepts as input a specific spaCy entity defined by the *entity* parameter and a list of all spaCy entities defined by the *entities* parameter.
#
# The function must find all entities (from *entities*) having the same surface form as *entity*. For each match between the entities, add the NER type to the dictionary *type_counts* and track the number of times each NER type appears.
#
# The *type_counts* dictionary would contain for example *McGeer* with ORG = 1, and PERSON = 1, because the function found 2 mentions of *McGeer*, each with a different type.

# %%
# ANSWER Q2 
def find_entity_types(entity, entities):
    '''
    Given a specific entity and a list of entities, finds all entities from the list that match surface form of the specified
    entity, but that could be of a different type.
    
    Returns the different NER types that have been classified for an entity and the count per NER type
    as a dictionary with the keys as the NER type and the value as the count
    '''
    type_counts = { }
    
    for token in entities:
        if token.text == entity.text:
            if token.label_ in type_counts:
                type_counts[token.label_] += 1
            else:
                type_counts[token.label_] = 1
        
    return type_counts

# %%
# Test the above to find the result when checking for the types of the entity 'Bourouiba' 
# from the document loaded above
print("All possible NER types for \"" + doc_sp.ents[64].text + "\" are " + str(find_entity_types(doc_sp.ents[64], doc_sp.ents)))
# Out:
# All possible NER types for "Bourouiba" are {'PERSON': 2, 'ORG': 2}

# %% [markdown]
# **(TO DO) Q3 - 2 marks**
# In the previous method, *find_entity_types*, we found all the possible entity types for a single entity.  Now, we want to use these to find the most common type.  For example, in the case of *McGeer*, it's a tie.  But for *Bourouiba*, there is one ORG type, and 2 PERSON type, so the most common would be PERSON.
#
# Complete the definition of the *most_common_type* function below. This function accepts as input a specific spaCy entity defined by the *entity* parameter and a list of all spaCy entities defined by the *entities* parameter.
#
# Note: You can handle ties as you please.  Also, make sure to use the function *find_entity_types* which you just wrote in Q2.

# %%
# ANSWER Q3 
def most_common_type(entity, entities):
    '''
    Given a specific entity and a list of entities, find the most similar entities and assign the
    NER type to entity based on the most common NER type assigned to entities of the same name (if there
    is a tie, you decide how to handle this).
    
    Returns the most common NER type based on similar entities
    '''
    # TODO
    NER_possibilities = find_entity_types(entity, entities)
    return max(NER_possibilities, key=NER_possibilities.get)

# %%
# Test the above to find the result when checking for the types of the entity 'Bourouiba' 
# from the document loaded above
print("The most common NER type to \"" + doc_sp.ents[64].text + "\" is " + most_common_type(doc_sp.ents[64], doc_sp.ents))
# Out:
# The most common NER type to "Bourouiba" is PERSON

# %% [markdown]
# Our first exploration (in Q2/Q3) was about frequency of occurrence.  We assumed the most common entity type could be the correct one.  Now, we'll explore the idea that the least ambiguous reference to an entity (the actual text) could be the correct one.  For example, *McGeer* is more ambiguous (shorter form) than *Allison McGeer* (longer form).  Often the longer form of reference to an entity is the least ambiguous.  But because it is long to write, we often use it sparingly in a text (perhaps only once) and then subsequent references to the same entity will use the shorter form.  For example, the text might mention *Allison McGeer* once, and then use the short form *McGeer* to refer to the same person many times in the document.
#
# In the course videos, we talked about the coreference chains. Thus, a chain contains long and short mentions, all referring to the same entity.
#
# The longer form is often referred to as the *normalized form*, and it is a form that we are likely to find in an external resource.  We'll see in part 3 of this notebook, when we do entity linking, that there is a Wikipedia entry for *Allison McGeer* that we could link to. We can consider the longer *Allison McGeer* form as the normalized form.

# %% [markdown]
# **(TO DO) Q4 (a) - 3 marks**
#
# You must write a function that will find the longest form that can match a mention.
#
# Your function will have the same *entity* and *entities* parameters, but this time the function must assign to *entity* the NER type of another entity in the *entities* iterator, that of the longest form found.
#
# Specifically, you must look through *entities* to find a normalized form of *entity*. In this scenario, the longest entity that contains *entity* as a substring will be considered the normalized form and should be returned.  If no longer form is found, the entity itself *entity* should be returned.
#
# Ex: *Lydia Bourouiba* is the normalized form of *Bourouiba*. Thus this entity should be returned.  But *McMaster University* is already the longest form, so if we search for a normalized form for that *entity*, the function should return *entity* itself.

# %%
# ANSWER Q4(a)
# Find the longest surface form within "entities" for which the surface form of "entity" is a substring
def assign_normalized_form(entity, entities):

    longestForm = entity
    for token in entities:
            if entity.text in token.text:
                longestForm = token
                break
    
    return longestForm

# %% [markdown]
# Let's test the above function, assuming the candidates are only found in the previous mentions, as often a long form is given first to (e.g. *Allison McGeer*) and subsequent forms are the short forms (e.g. *McGeer*).

# %%
# Testing using only the previous references as candidates
test = df["text"][1]
# Parse the text with spaCy
test_sp = sp(test)
for i, token in enumerate(test_sp.ents):
    ent = assign_normalized_form(test_sp.ents[i], test_sp.ents[0:i-1])
    print(str(i) + ": \"" + token.text + "\" is a " + token.label_ + "  " + ent.text + "  " + ent.label_)
# Out:
# 0: "weekly" is a DATE  weekly  DATE
# 1: "Saturday" is a DATE  Saturday  DATE
# 2: "morning" is a TIME  morning  TIME
# 3: "COVID-19" is a PERSON  COVID-19  PERSON
# 4: "two metres" is a QUANTITY  two metres  QUANTITY
# 5: "COVID-19" is a PERSON  COVID-19  PERSON
# 6: "the World Health Organization" is a ORG  the World Health Organization  ORG
# 7: "Touches" is a ORG  Touches  ORG
# 8: "WHO" is a ORG  WHO  ORG
# 9: "more than one metre" is a QUANTITY  more than one metre  QUANTITY
# 10: "the Public Health Agency of" is a ORG  the Public Health Agency of  ORG
# 11: "Canada" is a GPE  Canada  GPE
# 12: "at least two metres" is a QUANTITY  at least two metres  QUANTITY
# 13: "two" is a CARDINAL  two metres  QUANTITY
# 14: "2 metres" is a QUANTITY  2 metres  QUANTITY
# 15: "the 19th century" is a DATE  the 19th century  DATE
# 16: "1934" is a DATE  1934  DATE
# 17: "W.F. Wells" is a PERSON  W.F. Wells  PERSON
# 18: "the Harvard School of Public Health" is a ORG  the Harvard School of Public Health  ORG
# 19: "two metres" is a QUANTITY  two metres  QUANTITY
# 20: "Wells" is a PERSON  W.F. Wells  PERSON
# 21: "56,000+" is a QUANTITY  56,000+  QUANTITY
# 22: "Canada" is a GPE  Canada  GPE
# 23: "Saturday" is a DATE  Saturday  DATE
# 24: "Lydia Bourouiba" is a PERSON  Lydia Bourouiba  PERSON
# 25: "the Fluid Dynamics of Disease Transmission Laboratory" is a ORG  the Fluid Dynamics of Disease Transmission Laboratory  ORG
# 26: "the Massachusetts Institute of Technology" is a ORG  the Massachusetts Institute of Technology  ORG
# 27: "Bourouiba" is a PERSON  Lydia Bourouiba  PERSON
# 28: "Canadian" is a NORP  Canadian  NORP
# 29: "Mark Loeb" is a PERSON  Mark Loeb  PERSON
# 30: "Hamilton" is a PERSON  Hamilton  PERSON
# 31: "McMaster University " is a ORG  McMaster University   ORG
# 32: "RNA" is a ORG  RNA  ORG
# 33: "Wuhan" is a GPE  Wuhan  GPE
# 34: "China" is a GPE  China  GPE
# 35: "Nebraska" is a GPE  Nebraska  GPE
# 36: "COVID-19" is a PERSON  COVID-19  PERSON
# 37: "Canada" is a GPE  Canada  GPE
# 38: "Gary Moore" is a PERSON  Gary Moore  PERSON
# 39: "Allison McGeer" is a PERSON  Allison McGeer  PERSON
# 40: "Sinai Health" is a ORG  Sinai Health  ORG
# 41: "Toronto" is a GPE  Toronto  GPE
# 42: "COVID-19" is a PERSON  COVID-19  PERSON
# 43: "hundreds" is a CARDINAL  hundreds  CARDINAL
# 44: "hours" is a TIME  hours  TIME
# 45: "N-95" is a PRODUCT  N-95  PRODUCT
# 46: "McGeer" is a ORG  Allison McGeer  PERSON
# 47: "COVID-19" is a PRODUCT  COVID-19  PERSON
# 48: "five minutes" is a TIME  five minutes  TIME
# 49: "COVID-19" is a PERSON  COVID-19  PERSON
# 50: "McGeer" is a ORG  Allison McGeer  PERSON
# 51: "Bourouiba" is a ORG  Lydia Bourouiba  PERSON
# 52: "Bourouiba" is a ORG  Lydia Bourouiba  PERSON
# 53: "up to seven" is a CARDINAL  up to seven  CARDINAL
# 54: "Credit Lydia Bourouiba/MIT/" is a ORG  Credit Lydia Bourouiba/MIT/  ORG
# 55: "JAMA Networks" is a PERSON  JAMA Networks  PERSON
# 56: "Canadian" is a NORP  Canadian  NORP
# 57: "about one kilometre" is a QUANTITY  about one kilometre  QUANTITY
# 58: "two-metre" is a QUANTITY  two-metre  QUANTITY
# 59: "up to three minutes" is a TIME  up to three minutes  TIME
# 60: "Samira Mubareka" is a PERSON  Samira Mubareka  PERSON
# 61: "Sunnybrook Hospital" is a FAC  Sunnybrook Hospital  FAC
# 62: "Toronto" is a GPE  Toronto  GPE
# 63: "2-metre" is a QUANTITY  2-metre  QUANTITY
# 64: "Bourouiba" is a PERSON  Lydia Bourouiba  PERSON
# 65: "two metres" is a QUANTITY  two metres  QUANTITY
# 66: "March" is a DATE  March  DATE
# 67: "two metres" is a QUANTITY  two metres  QUANTITY
# 68: "two-metre" is a QUANTITY  two-metre  QUANTITY
# 69: "Second" is a ORDINAL  Second  ORDINAL
# 70: "COVID-19" is a PERSON  COVID-19  PERSON
# 71: "N95" is a ORG  N95  ORG
# 72: "U.S." is a GPE  U.S.  GPE
# 73: "Canadian" is a NORP  Canadian  NORP
# 74: "Justin Trudeau" is a PERSON  Justin Trudeau  PERSON
# 75: "April 2020" is a DATE  April 2020  DATE
# 76: "the New England Journal of Medicine" is a ORG  the New England Journal of Medicine  ORG
# 77: "the U.S. National Institutes of Health" is a ORG  the U.S. National Institutes of Health  ORG
# 78: "0:42" is a TIME  0:42  TIME
# 79: "U.S. National Institutes of Health" is a ORG  the U.S. National Institutes of Health  ORG
# 80: "less than 10 centimetres" is a QUANTITY  less than 10 centimetres  QUANTITY
# 81: "COVID-19" is a PERSON  COVID-19  PERSON
# 82: "2009" is a DATE  2009  DATE
# 83: "Journal of the Royal Society Interface" is a ORG  Journal of the Royal Society Interface  ORG
# 84: "2009" is a DATE  2009  DATE
# 85: "U.S." is a GPE  U.S.  GPE
# 86: "Singapore" is a GPE  Singapore  GPE
# 87: "N95" is a ORG  N95  ORG
# 88: "Gary S. Settles" is a PERSON  Gary S. Settles  PERSON
# 89: "Penn State University/Journal of the Royal Society Interface" is a ORG  Penn State University/Journal of the Royal Society Interface  ORG
# 90: "The World Health Organization" is a ORG  The World Health Organization  ORG
# 91: "Los Angeles" is a GPE  Los Angeles  GPE
# 92: "Italy" is a GPE  Italy  GPE
# 93: "Austria" is a GPE  Austria  GPE
# 94: "Saturday" is a DATE  Saturday  DATE
# 95: "morning" is a TIME  morning  TIME

# %% [markdown]
# **(TO DO) Q4 (b) - 2 marks**
#
# Do other tests without the limitation of using only longer forms mentioned before an entity (see *test_sp.ents[0:i-1]* in the code above), try searching before and after.  Or try an interval (e.g. max N entities before or after).  Explain what you tested.  Any difference?  Provide at least 2 examples of changes that you notice.

# %%
# ANSWER Q4(b)
# Do a different test


for i, token in enumerate(test_sp.ents):
    ent = assign_normalized_form(test_sp.ents[i], test_sp.ents)
    print(str(i) + ": \"" + token.text + "\" is a " + token.label_ + "  " + ent.text + "  " + ent.label_)

# Testing using only the subsequent references as candidates
for i, token in enumerate(test_sp.ents):
    ent = assign_normalized_form(test_sp.ents[i], test_sp.ents[i+1:i-1])
    print(str(i) + ": \"" + token.text + "\" is a " + token.label_ + "  " + ent.text + "  " + ent.label_)
# Out:
# 0: "weekly" is a DATE  weekly  DATE
# 1: "Saturday" is a DATE  Saturday  DATE
# 2: "morning" is a TIME  morning  TIME
# 3: "COVID-19" is a PERSON  COVID-19  PERSON
# 4: "two metres" is a QUANTITY  two metres  QUANTITY
# 5: "COVID-19" is a PERSON  COVID-19  PERSON
# 6: "the World Health Organization" is a ORG  the World Health Organization  ORG
# 7: "Touches" is a ORG  Touches  ORG
# 8: "WHO" is a ORG  WHO  ORG
# 9: "more than one metre" is a QUANTITY  more than one metre  QUANTITY
# 10: "the Public Health Agency of" is a ORG  the Public Health Agency of  ORG
# 11: "Canada" is a GPE  Canada  GPE
# 12: "at least two metres" is a QUANTITY  at least two metres  QUANTITY
# 13: "two" is a CARDINAL  two metres  QUANTITY
# 14: "2 metres" is a QUANTITY  2 metres  QUANTITY
# 15: "the 19th century" is a DATE  the 19th century  DATE
# 16: "1934" is a DATE  1934  DATE
# 17: "W.F. Wells" is a PERSON  W.F. Wells  PERSON
# 18: "the Harvard School of Public Health" is a ORG  the Harvard School of Public Health  ORG
# 19: "two metres" is a QUANTITY  two metres  QUANTITY
# 20: "Wells" is a PERSON  W.F. Wells  PERSON
# 21: "56,000+" is a QUANTITY  56,000+  QUANTITY
# 22: "Canada" is a GPE  Canada  GPE
# 23: "Saturday" is a DATE  Saturday  DATE
# 24: "Lydia Bourouiba" is a PERSON  Lydia Bourouiba  PERSON
# 25: "the Fluid Dynamics of Disease Transmission Laboratory" is a ORG  the Fluid Dynamics of Disease Transmission Laboratory  ORG
# 26: "the Massachusetts Institute of Technology" is a ORG  the Massachusetts Institute of Technology  ORG
# 27: "Bourouiba" is a PERSON  Lydia Bourouiba  PERSON
# 28: "Canadian" is a NORP  Canadian  NORP
# 29: "Mark Loeb" is a PERSON  Mark Loeb  PERSON
# 30: "Hamilton" is a PERSON  Hamilton  PERSON
# 31: "McMaster University " is a ORG  McMaster University   ORG
# 32: "RNA" is a ORG  RNA  ORG
# 33: "Wuhan" is a GPE  Wuhan  GPE
# 34: "China" is a GPE  China  GPE
# 35: "Nebraska" is a GPE  Nebraska  GPE
# 36: "COVID-19" is a PERSON  COVID-19  PERSON
# 37: "Canada" is a GPE  Canada  GPE
# 38: "Gary Moore" is a PERSON  Gary Moore  PERSON
# 39: "Allison McGeer" is a PERSON  Allison McGeer  PERSON
# 40: "Sinai Health" is a ORG  Sinai Health  ORG
# 41: "Toronto" is a GPE  Toronto  GPE
# 42: "COVID-19" is a PERSON  COVID-19  PERSON
# 43: "hundreds" is a CARDINAL  hundreds  CARDINAL
# 44: "hours" is a TIME  hours  TIME
# 45: "N-95" is a PRODUCT  N-95  PRODUCT
# 46: "McGeer" is a ORG  Allison McGeer  PERSON
# 47: "COVID-19" is a PRODUCT  COVID-19  PERSON
# 48: "five minutes" is a TIME  five minutes  TIME
# 49: "COVID-19" is a PERSON  COVID-19  PERSON
# 50: "McGeer" is a ORG  Allison McGeer  PERSON
# 51: "Bourouiba" is a ORG  Lydia Bourouiba  PERSON
# 52: "Bourouiba" is a ORG  Lydia Bourouiba  PERSON
# 53: "up to seven" is a CARDINAL  up to seven  CARDINAL
# 54: "Credit Lydia Bourouiba/MIT/" is a ORG  Credit Lydia Bourouiba/MIT/  ORG
# 55: "JAMA Networks" is a PERSON  JAMA Networks  PERSON
# 56: "Canadian" is a NORP  Canadian  NORP
# 57: "about one kilometre" is a QUANTITY  about one kilometre  QUANTITY
# 58: "two-metre" is a QUANTITY  two-metre  QUANTITY
# 59: "up to three minutes" is a TIME  up to three minutes  TIME
# 60: "Samira Mubareka" is a PERSON  Samira Mubareka  PERSON
# 61: "Sunnybrook Hospital" is a FAC  Sunnybrook Hospital  FAC
# 62: "Toronto" is a GPE  Toronto  GPE
# 63: "2-metre" is a QUANTITY  2-metre  QUANTITY
# 64: "Bourouiba" is a PERSON  Lydia Bourouiba  PERSON
# 65: "two metres" is a QUANTITY  two metres  QUANTITY
# 66: "March" is a DATE  March  DATE
# 67: "two metres" is a QUANTITY  two metres  QUANTITY
# 68: "two-metre" is a QUANTITY  two-metre  QUANTITY
# 69: "Second" is a ORDINAL  Second  ORDINAL
# 70: "COVID-19" is a PERSON  COVID-19  PERSON
# 71: "N95" is a ORG  N95  ORG
# 72: "U.S." is a GPE  U.S.  GPE
# 73: "Canadian" is a NORP  Canadian  NORP
# 74: "Justin Trudeau" is a PERSON  Justin Trudeau  PERSON
# 75: "April 2020" is a DATE  April 2020  DATE
# 76: "the New England Journal of Medicine" is a ORG  the New England Journal of Medicine  ORG
# 77: "the U.S. National Institutes of Health" is a ORG  the U.S. National Institutes of Health  ORG
# 78: "0:42" is a TIME  0:42  TIME
# 79: "U.S. National Institutes of Health" is a ORG  the U.S. National Institutes of Health  ORG
# 80: "less than 10 centimetres" is a QUANTITY  less than 10 centimetres  QUANTITY
# 81: "COVID-19" is a PERSON  COVID-19  PERSON
# 82: "2009" is a DATE  2009  DATE
# 83: "Journal of the Royal Society Interface" is a ORG  Journal of the Royal Society Interface  ORG
# 84: "2009" is a DATE  2009  DATE
# 85: "U.S." is a GPE  U.S.  GPE
# 86: "Singapore" is a GPE  Singapore  GPE
# 87: "N95" is a ORG  N95  ORG
# 88: "Gary S. Settles" is a PERSON  Gary S. Settles  PERSON
# 89: "Penn State University/Journal of the Royal Society Interface" is a ORG  Penn State University/Journal of the Royal Society Interface  ORG
# 90: "The World Health Organization" is a ORG  The World Health Organization  ORG
# 91: "Los Angeles" is a GPE  Los Angeles  GPE
# 92: "Italy" is a GPE  Italy  GPE
# 93: "Austria" is a GPE  Austria  GPE
# 94: "Saturday" is a DATE  Saturday  DATE
# 95: "morning" is a TIME  morning  TIME
# 0: "weekly" is a DATE  weekly  DATE
# 1: "Saturday" is a DATE  Saturday  DATE
# 2: "morning" is a TIME  morning  TIME
# 3: "COVID-19" is a PERSON  COVID-19  PERSON
# 4: "two metres" is a QUANTITY  two metres  QUANTITY
# 5: "COVID-19" is a PERSON  COVID-19  PERSON
# 6: "the World Health Organization" is a ORG  the World Health Organization  ORG
# 7: "Touches" is a ORG  Touches  ORG
# 8: "WHO" is a ORG  WHO  ORG
# 9: "more than one metre" is a QUANTITY  more than one metre  QUANTITY
# 10: "the Public Health Agency of" is a ORG  the Public Health Agency of  ORG
# 11: "Canada" is a GPE  Canada  GPE
# 12: "at least two metres" is a QUANTITY  at least two metres  QUANTITY
# 13: "two" is a CARDINAL  two  CARDINAL
# 14: "2 metres" is a QUANTITY  2 metres  QUANTITY
# 15: "the 19th century" is a DATE  the 19th century  DATE
# 16: "1934" is a DATE  1934  DATE
# 17: "W.F. Wells" is a PERSON  W.F. Wells  PERSON
# 18: "the Harvard School of Public Health" is a ORG  the Harvard School of Public Health  ORG
# 19: "two metres" is a QUANTITY  two metres  QUANTITY
# 20: "Wells" is a PERSON  Wells  PERSON
# 21: "56,000+" is a QUANTITY  56,000+  QUANTITY
# 22: "Canada" is a GPE  Canada  GPE
# 23: "Saturday" is a DATE  Saturday  DATE
# 24: "Lydia Bourouiba" is a PERSON  Lydia Bourouiba  PERSON
# 25: "the Fluid Dynamics of Disease Transmission Laboratory" is a ORG  the Fluid Dynamics of Disease Transmission Laboratory  ORG
# 26: "the Massachusetts Institute of Technology" is a ORG  the Massachusetts Institute of Technology  ORG
# 27: "Bourouiba" is a PERSON  Bourouiba  PERSON
# 28: "Canadian" is a NORP  Canadian  NORP
# 29: "Mark Loeb" is a PERSON  Mark Loeb  PERSON
# 30: "Hamilton" is a PERSON  Hamilton  PERSON
# 31: "McMaster University " is a ORG  McMaster University   ORG
# 32: "RNA" is a ORG  RNA  ORG
# 33: "Wuhan" is a GPE  Wuhan  GPE
# 34: "China" is a GPE  China  GPE
# 35: "Nebraska" is a GPE  Nebraska  GPE
# 36: "COVID-19" is a PERSON  COVID-19  PERSON
# 37: "Canada" is a GPE  Canada  GPE
# 38: "Gary Moore" is a PERSON  Gary Moore  PERSON
# 39: "Allison McGeer" is a PERSON  Allison McGeer  PERSON
# 40: "Sinai Health" is a ORG  Sinai Health  ORG
# 41: "Toronto" is a GPE  Toronto  GPE
# 42: "COVID-19" is a PERSON  COVID-19  PERSON
# 43: "hundreds" is a CARDINAL  hundreds  CARDINAL
# 44: "hours" is a TIME  hours  TIME
# 45: "N-95" is a PRODUCT  N-95  PRODUCT
# 46: "McGeer" is a ORG  McGeer  ORG
# 47: "COVID-19" is a PRODUCT  COVID-19  PRODUCT
# 48: "five minutes" is a TIME  five minutes  TIME
# 49: "COVID-19" is a PERSON  COVID-19  PERSON
# 50: "McGeer" is a ORG  McGeer  ORG
# 51: "Bourouiba" is a ORG  Bourouiba  ORG
# 52: "Bourouiba" is a ORG  Bourouiba  ORG
# 53: "up to seven" is a CARDINAL  up to seven  CARDINAL
# 54: "Credit Lydia Bourouiba/MIT/" is a ORG  Credit Lydia Bourouiba/MIT/  ORG
# 55: "JAMA Networks" is a PERSON  JAMA Networks  PERSON
# 56: "Canadian" is a NORP  Canadian  NORP
# 57: "about one kilometre" is a QUANTITY  about one kilometre  QUANTITY
# 58: "two-metre" is a QUANTITY  two-metre  QUANTITY
# 59: "up to three minutes" is a TIME  up to three minutes  TIME
# 60: "Samira Mubareka" is a PERSON  Samira Mubareka  PERSON
# 61: "Sunnybrook Hospital" is a FAC  Sunnybrook Hospital  FAC
# 62: "Toronto" is a GPE  Toronto  GPE
# 63: "2-metre" is a QUANTITY  2-metre  QUANTITY
# 64: "Bourouiba" is a PERSON  Bourouiba  PERSON
# 65: "two metres" is a QUANTITY  two metres  QUANTITY
# 66: "March" is a DATE  March  DATE
# 67: "two metres" is a QUANTITY  two metres  QUANTITY
# 68: "two-metre" is a QUANTITY  two-metre  QUANTITY
# 69: "Second" is a ORDINAL  Second  ORDINAL
# 70: "COVID-19" is a PERSON  COVID-19  PERSON
# 71: "N95" is a ORG  N95  ORG
# 72: "U.S." is a GPE  U.S.  GPE
# 73: "Canadian" is a NORP  Canadian  NORP
# 74: "Justin Trudeau" is a PERSON  Justin Trudeau  PERSON
# 75: "April 2020" is a DATE  April 2020  DATE
# 76: "the New England Journal of Medicine" is a ORG  the New England Journal of Medicine  ORG
# 77: "the U.S. National Institutes of Health" is a ORG  the U.S. National Institutes of Health  ORG
# 78: "0:42" is a TIME  0:42  TIME
# 79: "U.S. National Institutes of Health" is a ORG  U.S. National Institutes of Health  ORG
# 80: "less than 10 centimetres" is a QUANTITY  less than 10 centimetres  QUANTITY
# 81: "COVID-19" is a PERSON  COVID-19  PERSON
# 82: "2009" is a DATE  2009  DATE
# 83: "Journal of the Royal Society Interface" is a ORG  Journal of the Royal Society Interface  ORG
# 84: "2009" is a DATE  2009  DATE
# 85: "U.S." is a GPE  U.S.  GPE
# 86: "Singapore" is a GPE  Singapore  GPE
# 87: "N95" is a ORG  N95  ORG
# 88: "Gary S. Settles" is a PERSON  Gary S. Settles  PERSON
# 89: "Penn State University/Journal of the Royal Society Interface" is a ORG  Penn State University/Journal of the Royal Society Interface  ORG
# 90: "The World Health Organization" is a ORG  The World Health Organization  ORG
# 91: "Los Angeles" is a GPE  Los Angeles  GPE
# 92: "Italy" is a GPE  Italy  GPE
# 93: "Austria" is a GPE  Austria  GPE
# 94: "Saturday" is a DATE  Saturday  DATE
# 95: "morning" is a TIME  morning  TIME

# %% [markdown]
# **ANSWER Q4(b)**
#
# I ran two tests. The first test removes all limitations, and searches for the longer form before and after.
#
# The second tests searches subsequently (after).
#
# Since it is assumed that candidates are only found in previous mentions. I wanted to see what would happen for searches with no limitations and searches for candidates in the subsequent mentions. The algorithm seems to work better if there are no limitates on before and after, and if previous mentions are searched.  Issues with only searching subsequent mentions were that the long form did not always replace the short form. For example, for subsequent searches "Bourouiba" was not always replaced by its long form "Lydia Bourouiba". The same with "Samira Mubraeka"

# %% [markdown]
# **(TO DO) Q5 - 5 marks**
# Use a different news article in the corpus, the 7th article, so index 6.
#
# (a) (2 marks) Run the two approaches (most frequent, longest form).  For each entity found in the text, print its original entity type (as found by spaCy, then the most common entity type, and then the normalized form with its entity type. \
# (b) (3 marks) Analyze and discuss the results.  Do you think these text coherence approaches help or are they too simple?  Are there conflicting results (the two approaches give different results).  If yes, show examples that are different.

# %%
# ANSWER Q5(a) 
# Select document index 6
doc6 = df["text"][6]
doc6_sp = sp(doc6)
for i, token in enumerate(doc6_sp.ents):
    mct = most_common_type(doc6_sp.ents[i], doc6_sp.ents)
    asm = assign_normalized_form(doc6_sp.ents[i], doc6_sp.ents)
    
    print("{}: \"{}\" \noriginal entity type: {} \nmost common entity type: {} \nNormalized Form: \"{}\" with entity type: {} "
          .format(str(i+1), token.text, token.label_, mct, asm.text, asm.label_ ))

    
#     ent = assign_normalized_form(test_sp.ents[i], test_sp.ents)
#     print(str(i) + ": \"" + token.text + "\" is a " + token.label_ + "  " + ent.text + "  " + ent.label_)
# Out:
# 1: "Canada"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Canada" with entity type: GPE
# 2: "C.D. Howe"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "C.D. Howe" with entity type: ORG
# 3: "Monday"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "Monday" with entity type: DATE
# 4: "Alberta"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Alberta" with entity type: GPE
# 5: "first"
# original entity type: ORDINAL
# most common entity type: ORDINAL
# Normalized Form: "first" with entity type: ORDINAL
# 6: "Saturday"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "Saturday" with entity type: DATE
# 7: "Air Canada"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "Air Canada" with entity type: ORG
# 8: "Christmas"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "Christmas" with entity type: DATE
# 9: "Canadians"
# original entity type: NORP
# most common entity type: NORP
# Normalized Form: "Canadians" with entity type: NORP
# 10: "more than $1.2 million"
# original entity type: MONEY
# most common entity type: MONEY
# Normalized Form: "more than $1.2 million" with entity type: MONEY
# 11: "COVID-19"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "COVID-19" with entity type: PERSON
# 12: "Park Golf Course"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "Park Golf Course" with entity type: PERSON
# 13: "England"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "England" with entity type: GPE
# 14: "Peter Cziborra/Reuters"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "Peter Cziborra/Reuters" with entity type: PERSON
# 15: "months"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "months" with entity type: DATE
# 16: "CBC"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "CBC" with entity type: ORG
# 17: "Andre Mayer"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "Andre Mayer" with entity type: PERSON
# 18: "Canada"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Canada" with entity type: GPE
# 19: "19th-century"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "19th-century" with entity type: DATE
# 20: "2013"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "2013" with entity type: DATE
# 21: "Calgary"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Calgary" with entity type: GPE
# 22: "John Brown"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "John Brown" with entity type: PERSON
# 23: "the University of Calgary"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "the University of Calgary" with entity type: ORG
# 24: "COVID-19"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "COVID-19" with entity type: PERSON
# 25: "two-metre"
# original entity type: QUANTITY
# most common entity type: QUANTITY
# Normalized Form: "two-metre" with entity type: QUANTITY
# 26: "Last week"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "Last week" with entity type: DATE
# 27: "Italian"
# original entity type: NORP
# most common entity type: NORP
# Normalized Form: "Italian" with entity type: NORP
# 28: "Milan"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Milan" with entity type: GPE
# 29: "35 kilometres"
# original entity type: QUANTITY
# most common entity type: QUANTITY
# Normalized Form: "35 kilometres" with entity type: QUANTITY
# 30: "Berlin"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Berlin" with entity type: GPE
# 31: "Budapest"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Budapest" with entity type: GPE
# 32: "Mexico City"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Mexico City" with entity type: GPE
# 33: "Ahsan Habib"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "Ahsan Habib" with entity type: PERSON
# 34: "Dalhousie University"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "Dalhousie University" with entity type: ORG
# 35: "U.S."
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "U.S." with entity type: GPE
# 36: "Atlanta"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Atlanta" with entity type: GPE
# 37: "Chicago"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Chicago" with entity type: GPE
# 38: "Denver"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Denver" with entity type: GPE
# 39: "Habib"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "Ahsan Habib" with entity type: PERSON
# 40: "Brown"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "John Brown" with entity type: PERSON
# 41: "Calgary"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Calgary" with entity type: GPE
# 42: "Housebrand"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "Housebrand" with entity type: ORG
# 43: "Zoom"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "Zoom" with entity type: PERSON
# 44: "The National The At"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "The National The At" with entity type: ORG
# 45: "Quebec"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Quebec" with entity type: GPE
# 46: "COVID-19"
# original entity type: PRODUCT
# most common entity type: PERSON
# Normalized Form: "COVID-19" with entity type: PERSON
# 47: "Conservative"
# original entity type: NORP
# most common entity type: NORP
# Normalized Form: "Conservative" with entity type: NORP
# 48: "Canada"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Canada" with entity type: GPE
# 49: "C.D. Howe"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "C.D. Howe" with entity type: ORG
# 50: "Canada"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Canada" with entity type: GPE
# 51: "COVID-19"
# original entity type: PRODUCT
# most common entity type: PERSON
# Normalized Form: "COVID-19" with entity type: PERSON
# 52: "the C.D. Howe Institute's"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "the C.D. Howe Institute's" with entity type: ORG
# 53: "Business Cycle Council"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "Business Cycle Council" with entity type: ORG
# 54: "today"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "today" with entity type: DATE
# 55: "Canada"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Canada" with entity type: GPE
# 56: "February"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "February" with entity type: DATE
# 57: "one"
# original entity type: CARDINAL
# most common entity type: CARDINAL
# Normalized Form: "one" with entity type: CARDINAL
# 58: "two"
# original entity type: CARDINAL
# most common entity type: CARDINAL
# Normalized Form: "two-metre" with entity type: QUANTITY
# 59: "three-month"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "three-month" with entity type: DATE
# 60: "two quarters"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "two quarters" with entity type: DATE
# 61: "less than two months old"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "less than two months old" with entity type: DATE
# 62: "Canada"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Canada" with entity type: GPE
# 63: "first"
# original entity type: ORDINAL
# most common entity type: ORDINAL
# Normalized Form: "first" with entity type: ORDINAL
# 64: "Canada"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Canada" with entity type: GPE
# 65: "2008"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "2008" with entity type: DATE
# 66: "March"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "March" with entity type: DATE
# 67: "April"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "April" with entity type: DATE
# 68: "the entire month"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "the entire month" with entity type: DATE
# 69: "Canada"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Canada" with entity type: GPE
# 70: "Monday"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "Monday" with entity type: DATE
# 71: "Alberta"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Alberta" with entity type: GPE
# 72: "Saturday"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "Saturday" with entity type: DATE
# 73: "today"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "today" with entity type: DATE
# 74: "Monday"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "Monday" with entity type: DATE
# 75: "Today"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "Today" with entity type: DATE
# 76: "Doug Ford"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "Doug Ford" with entity type: PERSON
# 77: "Alberta"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Alberta" with entity type: GPE
# 78: "Jason Kenney"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "Jason Kenney" with entity type: PERSON
# 79: "first"
# original entity type: ORDINAL
# most common entity type: ORDINAL
# Normalized Form: "first" with entity type: ORDINAL
# 80: "Alberta"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Alberta" with entity type: GPE
# 81: "Saturday"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "Saturday" with entity type: DATE
# 82: "mid-May."
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "mid-May." with entity type: DATE
# 83: "Kenney"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "Jason Kenney" with entity type: PERSON
# 84: "Thursday"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "Thursday" with entity type: DATE
# 85: "Monday"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "Monday" with entity type: DATE
# 86: "Kenney"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "Jason Kenney" with entity type: PERSON
# 87: "summer"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "summer" with entity type: DATE
# 88: "Canada"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Canada" with entity type: GPE
# 89: "Air Canada"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "Air Canada" with entity type: ORG
# 90: "Christmas"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "Christmas" with entity type: DATE
# 91: "Air Canada"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "Air Canada" with entity type: ORG
# 92: "the time winter holidays"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "the time winter holidays" with entity type: DATE
# 93: "Canadians"
# original entity type: NORP
# most common entity type: NORP
# Normalized Form: "Canadians" with entity type: NORP
# 94: "Tim Strauss"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "Tim Strauss" with entity type: PERSON
# 95: "Canadian"
# original entity type: NORP
# most common entity type: NORP
# Normalized Form: "Canadians" with entity type: NORP
# 96: "Air Canada"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "Air Canada" with entity type: ORG
# 97: "more than 90"
# original entity type: CARDINAL
# most common entity type: CARDINAL
# Normalized Form: "more than 90" with entity type: CARDINAL
# 98: "Canadian"
# original entity type: NORP
# most common entity type: NORP
# Normalized Form: "Canadians" with entity type: NORP
# 99: "Toronto"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Toronto" with entity type: GPE
# 100: "today"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "today" with entity type: DATE
# 101: "North American"
# original entity type: NORP
# most common entity type: NORP
# Normalized Form: "North American" with entity type: NORP
# 102: "Air Canada"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "Air Canada" with entity type: ORG
# 103: "Sunwing"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "Sunwing" with entity type: ORG
# 104: "American Airlines"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "American Airlines" with entity type: ORG
# 105: "Transport Canada"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "Transport Canada" with entity type: ORG
# 106: "two metres"
# original entity type: QUANTITY
# most common entity type: QUANTITY
# Normalized Form: "two metres" with entity type: QUANTITY
# 107: "Air Canada"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "Air Canada" with entity type: ORG
# 108: "Christmas"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "Christmas" with entity type: DATE
# 109: "Helane Becker"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "Helane Becker" with entity type: PERSON
# 110: "first"
# original entity type: ORDINAL
# most common entity type: ORDINAL
# Normalized Form: "first" with entity type: ORDINAL
# 111: "Becker"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "Helane Becker" with entity type: PERSON
# 112: "THE SCIENCE Is Canada"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "THE SCIENCE Is Canada" with entity type: ORG
# 113: "CBC News"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "CBC News" with entity type: ORG
# 114: "U.S."
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "U.S." with entity type: GPE
# 115: "COVID-19"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "COVID-19" with entity type: PERSON
# 116: "U.S."
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "U.S." with entity type: GPE
# 117: "Anthony Fauci"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "Anthony Fauci" with entity type: PERSON
# 118: "Canada"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Canada" with entity type: GPE
# 119: "Canada"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Canada" with entity type: GPE
# 120: "Health Canada"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "Health Canada" with entity type: ORG
# 121: "Gilead"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "Gilead" with entity type: ORG
# 122: "CBC News"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "CBC News" with entity type: ORG
# 123: "Gilead"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "Gilead" with entity type: ORG
# 124: "Canada"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Canada" with entity type: GPE
# 125: "Alberta"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Alberta" with entity type: GPE
# 126: "daily"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "daily" with entity type: DATE
# 127: "Grace Horsfall Couldwell"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "Grace Horsfall Couldwell" with entity type: PERSON
# 128: "Alberta"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Alberta" with entity type: GPE
# 129: "Lori Toma"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "Lori Toma" with entity type: PERSON
# 130: "Nancy Horsfall Couldwell"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "Nancy Horsfall Couldwell" with entity type: PERSON
# 131: "Alta"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "Alta" with entity type: ORG
# 132: "Facebook"
# original entity type: PRODUCT
# most common entity type: PRODUCT
# Normalized Form: "Facebook" with entity type: PRODUCT
# 133: "hour-long"
# original entity type: TIME
# most common entity type: TIME
# Normalized Form: "hour-long" with entity type: TIME
# 134: "20 to 30"
# original entity type: CARDINAL
# most common entity type: CARDINAL
# Normalized Form: "20 to 30" with entity type: CARDINAL
# 135: "more than 1,500"
# original entity type: CARDINAL
# most common entity type: CARDINAL
# Normalized Form: "more than 1,500" with entity type: CARDINAL
# 136: "more than one"
# original entity type: CARDINAL
# most common entity type: CARDINAL
# Normalized Form: "more than one" with entity type: CARDINAL
# 137: "Two years ago"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "Two years ago" with entity type: DATE
# 138: "100 days"
# original entity type: DATE
# most common entity type: DATE
# Normalized Form: "100 days" with entity type: DATE
# 139: "COVID-19"
# original entity type: PERSON
# most common entity type: PERSON
# Normalized Form: "COVID-19" with entity type: PERSON
# 140: "Canada"
# original entity type: GPE
# most common entity type: GPE
# Normalized Form: "Canada" with entity type: GPE
# 141: "CBC News"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "CBC News" with entity type: ORG
# 142: "CBC News Network"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "CBC News Network" with entity type: ORG
# 143: "CBC News Network"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "CBC News Network" with entity type: ORG
# 144: "CBC"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "CBC" with entity type: ORG
# 145: "CBC News Network"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "CBC News Network" with entity type: ORG
# 146: "CBC News"
# original entity type: ORG
# most common entity type: ORG
# Normalized Form: "CBC News" with entity type: ORG

# %% [markdown]
# **ANSWER Q5(b)**
#
# Coherence approaches seemed too simple and did not help for this data set. The two approaches gave conflicting results.

# %% [markdown]
# **PART 3 - Entity Linking / Text enhancement**
#
# For the third part of this notebook, we will be exploring how we can enhance the text of documents. In this scenario, we will be enhancing the text by performing entity linking. This means that we will attempt the linking of the entities that are detected by spaCy's NER to an active webpage that a reader can click on to obtain more information regarding the entity. Wikipedia, is a very good resource to find out more information about an entity, and we will use this resource for entity linking.
#
# Before going straight into an example through code, below is an example of how a text with no entity linking compares to a text with entity linking:
#
# *No entity linking:* \
# During the pandemic, U.S. cities such as Atlanta, Chicago and Denver have made several adjustments to their transit systems.
#
# *With entity linking:*  \
# During the pandemic, U.S. cities such as <a href="http://en.wikipedia.org/wiki/Atlanta">Atlanta</a>, <a href="http://en.wikipedia.org/wiki/Chicago">Chicago</a> and <a href="http://en.wikipedia.org/wiki/Denver">Denver</a> have made several adjustments to their transit systems.

# %% [markdown]
# Transforming a text automatically with clickable links requires several processing at the character string level. In this Notebook, we will be satisfied with finding the links without making the replacements directly in the text. This will allow us to explore the Wikipedia resource, and understand the difficulties relating to "entity linking" without wasting too much time in the complex manipulation of strings.
#
# For example, with the document (index 6), we would like to be able to link the entities found by spaCy to the most likely wikipedia page giving access to additional information on that entity.
#
# **This enriched list format shown is the type of output requested in question Q6 below.**  For coding simplicity, we will use this type of output instead of an article in which the text would replaced by links.
#
# 0: "Coronavirus Brief" is a ORG found at http://en.wikipedia.org/wiki/Coronavirus_Brief \
# 1: "CBC" is a ORG found at http://en.wikipedia.org/wiki/CBC \
# 2: "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada \
# 3: "C.D. Howe" is a PERSON found at http://en.wikipedia.org/wiki/C.D._Howe \
# 4: ... \

# %% [markdown]
# **(TO DO) Q6 - 5 marks**
# Write the code needed to search a wikipedia page for the entities found by spaCy (as shown above) in a particular document.
#
# *You can write the code as you like, but it must include the following elements:*
#
# *   (a) A restriction on which type of entities you are linking.  For example, Wikipedia does not contain quantities (such as "two meters") so it would be inappropriate to include a link to a quantity.
# *   (b) The use of the *normalized form* of the entity to perform the linking.  For example, *Allison McGeer* does have a Wikipedia page (https://en.wikipedia.org/wiki/Allison_McGeer) that you can link to, even when you are looking at the entity with label *McGeer*.  So make sure to use the function you developed in Q4.
# *   (c) Attention:  the wikipedia page uses underscores. So for example, *McMaster University* should be transformed to https://en.wikipedia.org/wiki/McMaster_University (with an underscore between *McMaster* and *University*
# *   (d) Include one element of post-processing on the longer form.  For example *the C.D. Howe Institute's* is tagged by spaCy, but Wikipedia will contain *C.D._Howe_Institute*.  You can remove small particules like *the* to augment the chance of linking.
# *   (e) For a specific document, output the surface form, entity type and link to Wikipedia in a list as shown above
#
# Be sure to put comments in your code to make it clear what corresponds to parts (a), (b), (c), (d) and (e).
#
# There will be probably many links that you include that will link to wikipedia pages that do not exist.  That's ok, don't worry about that.  Wikipedia does not contain everything, and some normalized forms will not be there.  You will be asked to discuss this later in Q7.

# %%
# ANSWER - Q6
import re

doc6 = df["text"][6]
doc6_sp = sp(doc6)

# I placed my solution in a function so that it could be easily used by question 7
def generateEntityLinks(docx):
    for i, token in enumerate(docx.ents):

        # b) obtaining the normalized form of the entity
        normalized_token = assign_normalized_form(docx.ents[i], docx.ents)

#         For Q7, restrictions applied for various entity types
#         Uncomment and recomment to test, also uncomment a) 
#         if  normalized_token.label_ == "GPE":
#         if  normalized_token.label_ == "PERSON":
#         if  normalized_token.label_ == "ORG":
            
        # a) restrictions for QUANTITY. 
        if  normalized_token.label_ != "QUANTITY":

            # d) post-processing to remove some small particules to improve chances of linking to wikipedia. 
            #    Notes beside or above the code

            # convert the normalized form into a string that will be processed
            unprocessed_form = normalized_token.text 

            # remove all the articles from the beginning of a sentence to augment chance of a wikipedia link. 
            processed_form1 = re.sub(r'^(the |The |tHe |thE |tHE |THe |ThE |THE |a |A |an |An |AN )', '', unprocessed_form)

            # remove all punctuations that cause problems when creating a wikipedia link, but NOT periods(.) or hyphens(-)
            # also, remove punctuations and the string that comes after it (Example: Institute's -> Institute, and Peter Cziborra/Reuters -> Peter Cziborra), , but NOT periods(.) or hyphens(-)
            processed_form2 = re.sub(r'[\;:,\?\"\'\/!]\w*$', '', processed_form1)

            # remove all whitespace at the beginning of a string
            processed_final = re.sub(r'^\s', '', processed_form2)

            # c) transforming all white spaces into underscores and then concatenating it to create the wiki search link
            wiki_search_link = 'http://en.wikipedia.org/wiki/' + processed_final.replace(" ","_")

            # e) output of surface form, entity type, and link to wikipedia
            print("{}: {}, \"{}\" is a {} found at {}".format(i, token.text, normalized_token.text, normalized_token.label_, wiki_search_link))


generateEntityLinks(doc6_sp)
# Out:
# 0: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 1: C.D. Howe, "C.D. Howe" is a ORG found at http://en.wikipedia.org/wiki/C.D._Howe
# 2: Monday, "Monday" is a DATE found at http://en.wikipedia.org/wiki/Monday
# 3: Alberta, "Alberta" is a GPE found at http://en.wikipedia.org/wiki/Alberta
# 4: first, "first" is a ORDINAL found at http://en.wikipedia.org/wiki/first
# 5: Saturday, "Saturday" is a DATE found at http://en.wikipedia.org/wiki/Saturday
# 6: Air Canada, "Air Canada" is a ORG found at http://en.wikipedia.org/wiki/Air_Canada
# 7: Christmas, "Christmas" is a DATE found at http://en.wikipedia.org/wiki/Christmas
# 8: Canadians, "Canadians" is a NORP found at http://en.wikipedia.org/wiki/Canadians
# 9: more than $1.2 million, "more than $1.2 million" is a MONEY found at http://en.wikipedia.org/wiki/more_than_$1.2_million
# 10: COVID-19, "COVID-19" is a PERSON found at http://en.wikipedia.org/wiki/COVID-19
# 11: Park Golf Course, "Park Golf Course" is a PERSON found at http://en.wikipedia.org/wiki/Park_Golf_Course
# 12: England, "England" is a GPE found at http://en.wikipedia.org/wiki/England
# 13: Peter Cziborra/Reuters, "Peter Cziborra/Reuters" is a PERSON found at http://en.wikipedia.org/wiki/Peter_Cziborra
# 14: months, "months" is a DATE found at http://en.wikipedia.org/wiki/months
# 15: CBC, "CBC" is a ORG found at http://en.wikipedia.org/wiki/CBC
# 16: Andre Mayer, "Andre Mayer" is a PERSON found at http://en.wikipedia.org/wiki/Andre_Mayer
# 17: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 18: 19th-century, "19th-century" is a DATE found at http://en.wikipedia.org/wiki/19th-century
# 19: 2013, "2013" is a DATE found at http://en.wikipedia.org/wiki/2013
# 20: Calgary, "Calgary" is a GPE found at http://en.wikipedia.org/wiki/Calgary
# 21: John Brown, "John Brown" is a PERSON found at http://en.wikipedia.org/wiki/John_Brown
# 22: the University of Calgary, "the University of Calgary" is a ORG found at http://en.wikipedia.org/wiki/University_of_Calgary
# 23: COVID-19, "COVID-19" is a PERSON found at http://en.wikipedia.org/wiki/COVID-19
# 25: Last week, "Last week" is a DATE found at http://en.wikipedia.org/wiki/Last_week
# 26: Italian, "Italian" is a NORP found at http://en.wikipedia.org/wiki/Italian
# 27: Milan, "Milan" is a GPE found at http://en.wikipedia.org/wiki/Milan
# 29: Berlin, "Berlin" is a GPE found at http://en.wikipedia.org/wiki/Berlin
# 30: Budapest, "Budapest" is a GPE found at http://en.wikipedia.org/wiki/Budapest
# 31: Mexico City, "Mexico City" is a GPE found at http://en.wikipedia.org/wiki/Mexico_City
# 32: Ahsan Habib, "Ahsan Habib" is a PERSON found at http://en.wikipedia.org/wiki/Ahsan_Habib
# 33: Dalhousie University, "Dalhousie University" is a ORG found at http://en.wikipedia.org/wiki/Dalhousie_University
# 34: U.S., "U.S." is a GPE found at http://en.wikipedia.org/wiki/U.S.
# 35: Atlanta, "Atlanta" is a GPE found at http://en.wikipedia.org/wiki/Atlanta
# 36: Chicago, "Chicago" is a GPE found at http://en.wikipedia.org/wiki/Chicago
# 37: Denver, "Denver" is a GPE found at http://en.wikipedia.org/wiki/Denver
# 38: Habib, "Ahsan Habib" is a PERSON found at http://en.wikipedia.org/wiki/Ahsan_Habib
# 39: Brown, "John Brown" is a PERSON found at http://en.wikipedia.org/wiki/John_Brown
# 40: Calgary, "Calgary" is a GPE found at http://en.wikipedia.org/wiki/Calgary
# 41: Housebrand, "Housebrand" is a ORG found at http://en.wikipedia.org/wiki/Housebrand
# 42: Zoom, "Zoom" is a PERSON found at http://en.wikipedia.org/wiki/Zoom
# 43: The National The At, "The National The At" is a ORG found at http://en.wikipedia.org/wiki/National_The_At
# 44: Quebec, "Quebec" is a GPE found at http://en.wikipedia.org/wiki/Quebec
# 45: COVID-19, "COVID-19" is a PERSON found at http://en.wikipedia.org/wiki/COVID-19
# 46: Conservative, "Conservative" is a NORP found at http://en.wikipedia.org/wiki/Conservative
# 47: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 48: C.D. Howe, "C.D. Howe" is a ORG found at http://en.wikipedia.org/wiki/C.D._Howe
# 49: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 50: COVID-19, "COVID-19" is a PERSON found at http://en.wikipedia.org/wiki/COVID-19
# 51: the C.D. Howe Institute's, "the C.D. Howe Institute's" is a ORG found at http://en.wikipedia.org/wiki/C.D._Howe_Institute
# 52: Business Cycle Council, "Business Cycle Council" is a ORG found at http://en.wikipedia.org/wiki/Business_Cycle_Council
# 53: today, "today" is a DATE found at http://en.wikipedia.org/wiki/today
# 54: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 55: February, "February" is a DATE found at http://en.wikipedia.org/wiki/February
# 56: one, "one" is a CARDINAL found at http://en.wikipedia.org/wiki/one
# 58: three-month, "three-month" is a DATE found at http://en.wikipedia.org/wiki/three-month
# 59: two quarters, "two quarters" is a DATE found at http://en.wikipedia.org/wiki/two_quarters
# 60: less than two months old, "less than two months old" is a DATE found at http://en.wikipedia.org/wiki/less_than_two_months_old
# 61: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 62: first, "first" is a ORDINAL found at http://en.wikipedia.org/wiki/first
# 63: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 64: 2008, "2008" is a DATE found at http://en.wikipedia.org/wiki/2008
# 65: March, "March" is a DATE found at http://en.wikipedia.org/wiki/March
# 66: April, "April" is a DATE found at http://en.wikipedia.org/wiki/April
# 67: the entire month, "the entire month" is a DATE found at http://en.wikipedia.org/wiki/entire_month
# 68: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 69: Monday, "Monday" is a DATE found at http://en.wikipedia.org/wiki/Monday
# 70: Alberta, "Alberta" is a GPE found at http://en.wikipedia.org/wiki/Alberta
# 71: Saturday, "Saturday" is a DATE found at http://en.wikipedia.org/wiki/Saturday
# 72: today, "today" is a DATE found at http://en.wikipedia.org/wiki/today
# 73: Monday, "Monday" is a DATE found at http://en.wikipedia.org/wiki/Monday
# 74: Today, "Today" is a DATE found at http://en.wikipedia.org/wiki/Today
# 75: Doug Ford, "Doug Ford" is a PERSON found at http://en.wikipedia.org/wiki/Doug_Ford
# 76: Alberta, "Alberta" is a GPE found at http://en.wikipedia.org/wiki/Alberta
# 77: Jason Kenney, "Jason Kenney" is a PERSON found at http://en.wikipedia.org/wiki/Jason_Kenney
# 78: first, "first" is a ORDINAL found at http://en.wikipedia.org/wiki/first
# 79: Alberta, "Alberta" is a GPE found at http://en.wikipedia.org/wiki/Alberta
# 80: Saturday, "Saturday" is a DATE found at http://en.wikipedia.org/wiki/Saturday
# 81: mid-May., "mid-May." is a DATE found at http://en.wikipedia.org/wiki/mid-May.
# 82: Kenney, "Jason Kenney" is a PERSON found at http://en.wikipedia.org/wiki/Jason_Kenney
# 83: Thursday, "Thursday" is a DATE found at http://en.wikipedia.org/wiki/Thursday
# 84: Monday, "Monday" is a DATE found at http://en.wikipedia.org/wiki/Monday
# 85: Kenney, "Jason Kenney" is a PERSON found at http://en.wikipedia.org/wiki/Jason_Kenney
# 86: summer, "summer" is a DATE found at http://en.wikipedia.org/wiki/summer
# 87: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 88: Air Canada, "Air Canada" is a ORG found at http://en.wikipedia.org/wiki/Air_Canada
# 89: Christmas, "Christmas" is a DATE found at http://en.wikipedia.org/wiki/Christmas
# 90: Air Canada, "Air Canada" is a ORG found at http://en.wikipedia.org/wiki/Air_Canada
# 91: the time winter holidays, "the time winter holidays" is a DATE found at http://en.wikipedia.org/wiki/time_winter_holidays
# 92: Canadians, "Canadians" is a NORP found at http://en.wikipedia.org/wiki/Canadians
# 93: Tim Strauss, "Tim Strauss" is a PERSON found at http://en.wikipedia.org/wiki/Tim_Strauss
# 94: Canadian, "Canadians" is a NORP found at http://en.wikipedia.org/wiki/Canadians
# 95: Air Canada, "Air Canada" is a ORG found at http://en.wikipedia.org/wiki/Air_Canada
# 96: more than 90, "more than 90" is a CARDINAL found at http://en.wikipedia.org/wiki/more_than_90
# 97: Canadian, "Canadians" is a NORP found at http://en.wikipedia.org/wiki/Canadians
# 98: Toronto, "Toronto" is a GPE found at http://en.wikipedia.org/wiki/Toronto
# 99: today, "today" is a DATE found at http://en.wikipedia.org/wiki/today
# 100: North American, "North American" is a NORP found at http://en.wikipedia.org/wiki/North_American
# 101: Air Canada, "Air Canada" is a ORG found at http://en.wikipedia.org/wiki/Air_Canada
# 102: Sunwing, "Sunwing" is a ORG found at http://en.wikipedia.org/wiki/Sunwing
# 103: American Airlines, "American Airlines" is a ORG found at http://en.wikipedia.org/wiki/American_Airlines
# 104: Transport Canada, "Transport Canada" is a ORG found at http://en.wikipedia.org/wiki/Transport_Canada
# 106: Air Canada, "Air Canada" is a ORG found at http://en.wikipedia.org/wiki/Air_Canada
# 107: Christmas, "Christmas" is a DATE found at http://en.wikipedia.org/wiki/Christmas
# 108: Helane Becker, "Helane Becker" is a PERSON found at http://en.wikipedia.org/wiki/Helane_Becker
# 109: first, "first" is a ORDINAL found at http://en.wikipedia.org/wiki/first
# 110: Becker, "Helane Becker" is a PERSON found at http://en.wikipedia.org/wiki/Helane_Becker
# 111: THE SCIENCE Is Canada, "THE SCIENCE Is Canada" is a ORG found at http://en.wikipedia.org/wiki/SCIENCE_Is_Canada
# 112: CBC News, "CBC News" is a ORG found at http://en.wikipedia.org/wiki/CBC_News
# 113: U.S., "U.S." is a GPE found at http://en.wikipedia.org/wiki/U.S.
# 114: COVID-19, "COVID-19" is a PERSON found at http://en.wikipedia.org/wiki/COVID-19
# 115: U.S., "U.S." is a GPE found at http://en.wikipedia.org/wiki/U.S.
# 116: Anthony Fauci, "Anthony Fauci" is a PERSON found at http://en.wikipedia.org/wiki/Anthony_Fauci
# 117: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 118: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 119: Health Canada, "Health Canada" is a ORG found at http://en.wikipedia.org/wiki/Health_Canada
# 120: Gilead, "Gilead" is a ORG found at http://en.wikipedia.org/wiki/Gilead
# 121: CBC News, "CBC News" is a ORG found at http://en.wikipedia.org/wiki/CBC_News
# 122: Gilead, "Gilead" is a ORG found at http://en.wikipedia.org/wiki/Gilead
# 123: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 124: Alberta, "Alberta" is a GPE found at http://en.wikipedia.org/wiki/Alberta
# 125: daily, "daily" is a DATE found at http://en.wikipedia.org/wiki/daily
# 126: Grace Horsfall Couldwell, "Grace Horsfall Couldwell" is a PERSON found at http://en.wikipedia.org/wiki/Grace_Horsfall_Couldwell
# 127: Alberta, "Alberta" is a GPE found at http://en.wikipedia.org/wiki/Alberta
# 128: Lori Toma, "Lori Toma" is a PERSON found at http://en.wikipedia.org/wiki/Lori_Toma
# 129: Nancy Horsfall Couldwell, "Nancy Horsfall Couldwell" is a PERSON found at http://en.wikipedia.org/wiki/Nancy_Horsfall_Couldwell
# 130: Alta, "Alta" is a ORG found at http://en.wikipedia.org/wiki/Alta
# 131: Facebook, "Facebook" is a PRODUCT found at http://en.wikipedia.org/wiki/Facebook
# 132: hour-long, "hour-long" is a TIME found at http://en.wikipedia.org/wiki/hour-long
# 133: 20 to 30, "20 to 30" is a CARDINAL found at http://en.wikipedia.org/wiki/20_to_30
# 134: more than 1,500, "more than 1,500" is a CARDINAL found at http://en.wikipedia.org/wiki/more_than_1
# 135: more than one, "more than one" is a CARDINAL found at http://en.wikipedia.org/wiki/more_than_one
# 136: Two years ago, "Two years ago" is a DATE found at http://en.wikipedia.org/wiki/Two_years_ago
# 137: 100 days, "100 days" is a DATE found at http://en.wikipedia.org/wiki/100_days
# 138: COVID-19, "COVID-19" is a PERSON found at http://en.wikipedia.org/wiki/COVID-19
# 139: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 140: CBC News, "CBC News" is a ORG found at http://en.wikipedia.org/wiki/CBC_News
# 141: CBC News Network, "CBC News Network" is a ORG found at http://en.wikipedia.org/wiki/CBC_News_Network
# 142: CBC News Network, "CBC News Network" is a ORG found at http://en.wikipedia.org/wiki/CBC_News_Network
# 143: CBC, "CBC" is a ORG found at http://en.wikipedia.org/wiki/CBC
# 144: CBC News Network, "CBC News Network" is a ORG found at http://en.wikipedia.org/wiki/CBC_News_Network
# 145: CBC News, "CBC News" is a ORG found at http://en.wikipedia.org/wiki/CBC_News

# %%
# I chose the 9th article, so index 8
doc8 = df["text"][8]
doc8_sp = sp(doc8)

generateEntityLinks(doc8_sp)
# Out:
# 0: The World Health Organization, "The World Health Organization" is a ORG found at http://en.wikipedia.org/wiki/World_Health_Organization
# 1: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 3: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 4: Saturday, "Saturday" is a DATE found at http://en.wikipedia.org/wiki/Saturday
# 5: The United Nations, "The United Nations" is a ORG found at http://en.wikipedia.org/wiki/United_Nations
# 6: 1948, "1948" is a DATE found at http://en.wikipedia.org/wiki/1948
# 7: 194, "1948" is a DATE found at http://en.wikipedia.org/wiki/1948
# 8: the World Health Organization, "the World Health Organization" is a ORG found at http://en.wikipedia.org/wiki/World_Health_Organization
# 9: Steven Hoffman, "Steven Hoffman" is a PERSON found at http://en.wikipedia.org/wiki/Steven_Hoffman
# 10: the Global Strategy Lab, "the Global Strategy Lab" is a ORG found at http://en.wikipedia.org/wiki/Global_Strategy_Lab
# 11: York University, "York University" is a ORG found at http://en.wikipedia.org/wiki/York_University
# 12: Toronto, "Toronto" is a GPE found at http://en.wikipedia.org/wiki/Toronto
# 13: the World Health Organization, "the World Health Organization" is a ORG found at http://en.wikipedia.org/wiki/World_Health_Organization
# 14: the last decades, "the last decades" is a DATE found at http://en.wikipedia.org/wiki/last_decades
# 15: 2005, "2005" is a DATE found at http://en.wikipedia.org/wiki/2005
# 16: the International Health Regulations, "the International Health Regulations" is a ORG found at http://en.wikipedia.org/wiki/International_Health_Regulations
# 17: COVID-19 The World Health Organization, "COVID-19 The World Health Organization" is a ORG found at http://en.wikipedia.org/wiki/COVID-19_The_World_Health_Organization
# 18: Donald Trump, "Donald Trump" is a PERSON found at http://en.wikipedia.org/wiki/Donald_Trump
# 19: U.S., "U.S." is a GPE found at http://en.wikipedia.org/wiki/U.S.
# 20: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 21: Amir Attaran, "Amir Attaran" is a PERSON found at http://en.wikipedia.org/wiki/Amir_Attaran
# 22: the University of Ottawa, "the University of Ottawa" is a ORG found at http://en.wikipedia.org/wiki/University_of_Ottawa
# 23: CBC, "CBC" is a ORG found at http://en.wikipedia.org/wiki/CBC
# 24: Sunday Edition the WHO, "Sunday Edition the WHO" is a WORK_OF_ART found at http://en.wikipedia.org/wiki/Sunday_Edition_the_WHO
# 25: Attaran, "Amir Attaran" is a PERSON found at http://en.wikipedia.org/wiki/Amir_Attaran
# 26: IHR, "IHR" is a ORG found at http://en.wikipedia.org/wiki/IHR
# 27: Tedros, "Tedros" is a PERSON found at http://en.wikipedia.org/wiki/Tedros
# 28: Chinese, "Chinese" is a NORP found at http://en.wikipedia.org/wiki/Chinese
# 29: Xi Jinping, "Xi Jinping" is a PERSON found at http://en.wikipedia.org/wiki/Xi_Jinping
# 30: Beijing, "Beijing" is a GPE found at http://en.wikipedia.org/wiki/Beijing
# 31: Jan. 28, "Jan. 28" is a DATE found at http://en.wikipedia.org/wiki/Jan._28
# 32: Amir Attaran, "Amir Attaran" is a PERSON found at http://en.wikipedia.org/wiki/Amir_Attaran
# 33: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 34: Naohiko Hatta/Reuters, "Naohiko Hatta/Reuters" is a ORG found at http://en.wikipedia.org/wiki/Naohiko_Hatta
# 35: Hoffman, "Steven Hoffman" is a PERSON found at http://en.wikipedia.org/wiki/Steven_Hoffman
# 36: China, "China" is a GPE found at http://en.wikipedia.org/wiki/China
# 37: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 38: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 39: Dec. 31, "Dec. 31" is a DATE found at http://en.wikipedia.org/wiki/Dec._31
# 40: China, "China" is a GPE found at http://en.wikipedia.org/wiki/China
# 41: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 42: Wuhan, "Wuhan" is a GPE found at http://en.wikipedia.org/wiki/Wuhan
# 43: Chinese, "Chinese" is a NORP found at http://en.wikipedia.org/wiki/Chinese
# 44: Hubei, "Hubei" is a GPE found at http://en.wikipedia.org/wiki/Hubei
# 45: weeks, "weeks" is a DATE found at http://en.wikipedia.org/wiki/weeks
# 46: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 47: a Public Health Emergency of International Concern, "a Public Health Emergency of International Concern" is a ORG found at http://en.wikipedia.org/wiki/Public_Health_Emergency_of_International_Concern
# 48: Jan. 30, "Jan. 30" is a DATE found at http://en.wikipedia.org/wiki/Jan._30
# 49: China, "China" is a GPE found at http://en.wikipedia.org/wiki/China
# 50: 6 crucial days, "6 crucial days" is a DATE found at http://en.wikipedia.org/wiki/6_crucial_days
# 51: a week, "a week" is a DATE found at http://en.wikipedia.org/wiki/week
# 52: Hoffman, "Steven Hoffman" is a PERSON found at http://en.wikipedia.org/wiki/Steven_Hoffman
# 53: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 54: Chinese, "Chinese" is a NORP found at http://en.wikipedia.org/wiki/Chinese
# 55: Wuhan, "Wuhan" is a GPE found at http://en.wikipedia.org/wiki/Wuhan
# 56: the weeks, "the weeks" is a DATE found at http://en.wikipedia.org/wiki/weeks
# 57: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 58: Canadian, "Canadian" is a NORP found at http://en.wikipedia.org/wiki/Canadian
# 59: China, "China" is a GPE found at http://en.wikipedia.org/wiki/China
# 60: David Mulroney, "David Mulroney" is a PERSON found at http://en.wikipedia.org/wiki/David_Mulroney
# 61: China, "China" is a GPE found at http://en.wikipedia.org/wiki/China
# 62: Beijing, "Beijing" is a GPE found at http://en.wikipedia.org/wiki/Beijing
# 63: China, "China" is a GPE found at http://en.wikipedia.org/wiki/China
# 64: Wuhan, "Wuhan" is a GPE found at http://en.wikipedia.org/wiki/Wuhan
# 65: China, "China" is a GPE found at http://en.wikipedia.org/wiki/China
# 66: Feb. 6, "Feb. 6" is a DATE found at http://en.wikipedia.org/wiki/Feb._6
# 67: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 68: China, "China" is a GPE found at http://en.wikipedia.org/wiki/China
# 69: China Daily/Reuters, "China Daily/Reuters" is a ORG found at http://en.wikipedia.org/wiki/China_Daily
# 70: Lynette Ong, "Lynette Ong" is a PERSON found at http://en.wikipedia.org/wiki/Lynette_Ong
# 71: the University of Toronto, "the University of Toronto" is a ORG found at http://en.wikipedia.org/wiki/University_of_Toronto
# 72: China, "China" is a GPE found at http://en.wikipedia.org/wiki/China
# 73: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 74: China, "China" is a GPE found at http://en.wikipedia.org/wiki/China
# 75: Chinese, "Chinese" is a NORP found at http://en.wikipedia.org/wiki/Chinese
# 76: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 77: China, "China" is a GPE found at http://en.wikipedia.org/wiki/China
# 78: CBC InvestigatesWhy, "CBC InvestigatesWhy" is a ORG found at http://en.wikipedia.org/wiki/CBC_InvestigatesWhy
# 79: China, "China" is a GPE found at http://en.wikipedia.org/wiki/China
# 80: Ong, "Lynette Ong" is a PERSON found at http://en.wikipedia.org/wiki/Lynette_Ong
# 81: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 82: China, "China" is a GPE found at http://en.wikipedia.org/wiki/China
# 83: millions, "millions" is a CARDINAL found at http://en.wikipedia.org/wiki/millions
# 84: Draconian, "Draconian" is a ORG found at http://en.wikipedia.org/wiki/Draconian
# 85: Wuhan, "Wuhan" is a GPE found at http://en.wikipedia.org/wiki/Wuhan
# 86: Jan. 27, "Jan. 27" is a DATE found at http://en.wikipedia.org/wiki/Jan._27
# 87: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 88: Bob Rae, "Bob Rae" is a PERSON found at http://en.wikipedia.org/wiki/Bob_Rae
# 89: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 90: STR, "STR" is a ORG found at http://en.wikipedia.org/wiki/STR
# 91: Getty Images, "Getty Images" is a PERSON found at http://en.wikipedia.org/wiki/Getty_Images
# 92: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 93: two to three weeks, "two to three weeks" is a DATE found at http://en.wikipedia.org/wiki/two_to_three_weeks
# 94: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 95: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 96: Australia, "Australia" is a GPE found at http://en.wikipedia.org/wiki/Australia
# 97: next month's, "next month's" is a DATE found at http://en.wikipedia.org/wiki/next_month
# 98: annual, "annual" is a DATE found at http://en.wikipedia.org/wiki/annual
# 99: the World Health Assembly, "the World Health Assembly" is a ORG found at http://en.wikipedia.org/wiki/World_Health_Assembly
# 100: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 101: U.S., "U.S." is a GPE found at http://en.wikipedia.org/wiki/U.S.
# 102: Donald Trump, "Donald Trump" is a PERSON found at http://en.wikipedia.org/wiki/Donald_Trump
# 103: U.S., "U.S." is a GPE found at http://en.wikipedia.org/wiki/U.S.
# 104: The Centers for Disease Control and Prevention, "The Centers for Disease Control and Prevention" is a ORG found at http://en.wikipedia.org/wiki/Centers_for_Disease_Control_and_Prevention
# 105: late January, "late January" is a DATE found at http://en.wikipedia.org/wiki/late_January
# 106: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 107: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 108: Theresa Tam, "Theresa Tam" is a PERSON found at http://en.wikipedia.org/wiki/Theresa_Tam
# 109: Tam, "Theresa Tam" is a PERSON found at http://en.wikipedia.org/wiki/Theresa_Tam
# 110: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 111: Theresa Tam, "Theresa Tam" is a PERSON found at http://en.wikipedia.org/wiki/Theresa_Tam
# 112: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 113: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 114: Theresa Tam, "Theresa Tam" is a PERSON found at http://en.wikipedia.org/wiki/Theresa_Tam
# 115: CBC’s, "CBC’s" is a ORG found at http://en.wikipedia.org/wiki/CBC’s
# 116: Rosemary Barton, "Rosemary Barton" is a PERSON found at http://en.wikipedia.org/wiki/Rosemary_Barton
# 117: the World Health Organization's, "the World Health Organization's" is a ORG found at http://en.wikipedia.org/wiki/World_Health_Organization
# 118: Justin Trudeau, "Justin Trudeau" is a PERSON found at http://en.wikipedia.org/wiki/Justin_Trudeau
# 119: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 120: Bob Rae, "Bob Rae" is a PERSON found at http://en.wikipedia.org/wiki/Bob_Rae
# 121: Canada, "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada
# 122: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 123: Wuhan, "Wuhan" is a GPE found at http://en.wikipedia.org/wiki/Wuhan
# 124: 50%, "50%" is a PERCENT found at http://en.wikipedia.org/wiki/50%
# 125: Rae, "Bob Rae" is a PERSON found at http://en.wikipedia.org/wiki/Bob_Rae
# 126: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 127: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 128: Rae, "Bob Rae" is a PERSON found at http://en.wikipedia.org/wiki/Bob_Rae
# 129: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 130: Chinese, "Chinese" is a NORP found at http://en.wikipedia.org/wiki/Chinese
# 131: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO
# 132: WHO, "WHO" is a ORG found at http://en.wikipedia.org/wiki/WHO

# %% [markdown]
# **(TO DO) Q7 - 5 marks**
# Perform a qualitative evaluation of the entity linking method you wrote in Q6.  For your qualitative evaluation, you must choose a document (any one you want from the corpus of covid-19 related news, but make sure to mention which one) and run your method on that document.  Answer the following questions :
#
# * a. Give 2 examples of entities where the longer form was found in Wikipedia.  Is the page found appropriate? Would the shorter form be found too? Would it link to the same page?
# * b.  Give 2 examples of entities where the wikipedia page did not exist.  Why is that?  Was the form searched on incorrect?
# * c.  Try restricting your search with different entity types.  Do you see DATE covered by Wikipedia?  What about PERSON or GPE?  Discuss the coverage of different entity types by giving some examples.
#
#
# **For Question 7, I inserted a cell above for my test because I wasn't sure if I was supposed to re-use the cell from Q6.
#   However, this helped me to better compare the results.**

# %% [markdown]
# **ANSWER Q7**
#
# For my qualitative evaluation, I choose article 9 (index 8).
#
# a. Two examples of entities where the longer form was found on wikipedia:
#    1. "Theresa Tam" (https://en.wikipedia.org/wiki/Theresa_Tam)
#    2. "Amir Attaran" (https://en.wikipedia.org/wiki/Amir_Attaran)
#
# "Theresa Tam" is a longer form that was found on Wikipedia, and the page found was appropriate. The shorter form was "Tam", which did not link to the same page and it was not actually found on wikipedia. But, it did link to a Wikipedia page with various entities that referred to the string "Tam", some of which were people, or story characters with the name or surname of "Tam" and some of which were acronyms like "TAM". Thus, the page found by the shorter form was not appropriate.
#
# "Amir Attaran" is the longer form where an appropriate page was found on Wikipedia. However, the shorter form "Attaran" was not found to link to any page.
#
#
# b. Two examples of entities where the wikipedia page did not exist:
#    1. "Jan. 28" (https://en.wikipedia.org/wiki/Jan._28)
#    2. "Lynette Ong" (http://en.wikipedia.org/wiki/Lynette_Ong)
#
# A link generated by "Jan. 28" does not exist. I thought the form searched was incorrect, but another link generated in the exact same way for "Dec. 31" (https://en.wikipedia.org/wiki/Dec._31) worked. Perhaps, this is because December 31 is a much more popular date since it is New Years Eve.
#
# "Lynette Ong" did not generate a link that exists for wikipedia. The form searched was correct, but I believe a page did not exist because the entity was a person who was not very well-known.
#
# I am including a note about "A Public Health Emergency of International Concern" because I feel that it demonstrates a situation where an incorrect form did not lead to an existing page. However, when I adjusted my algorithm to remove the article "a", it created an appropriate link.
# https://en.wikipedia.org/wiki/Public_Health_Emergency_of_International_Concern
#
# c. I restricted different types in the code in Q6, such as ORG, GPE, and PERSON.
#
# - ORG had very good results if the string was processed appropriately to remove articles such as "a" or "the", and any other noise. An example would be "University of Toronto" produced a appropriate page, but "the University of Toronto" did not.
#
# - PERSON had very good coverage with the normalized long form. An example would be "Theresa Tam" from section a). However, PERSON did have issues finding pages for people that were not well-known, such as "Lynette Ong" also from the previous example.
#
# - GPE had the best results for the short form. I beleive this is because it did not usually normalize as often as the other surface forms. However, tests on other data sets may disprove this. Examples that include appropriate pages include: "Canada" and "U.S."
#
# - DATE has inconsistent coverage by wikipedia. A DATE that was covered by wikipedia usually had a more specific surface form, such as "2005" or "Saturday". However, for a DATE labelled as "today", Wikipedia linked to a page listing more than one entity related to that surface form. Additionally, other surface forms labelled as DATE did not have a page that existed, such as "late January". Restricting results to not include DATE seemed to produce more viable links.
#
# - Both CARDINAL and ORDINAL seemed to have the worst results overall. Restricting results to not include CARDINAL and ORDINAL seemed to produce more viable links. Examples include "first" which linked to a page indicating multiple entities, and "20 to 30" (from index 6), which did not have a page.
